# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import binary_crossentropy
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
import numpy as np
import matplotlib.pyplot as plt
import math
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
np.random.seed(2)

# %%
base_dir = '/Users/jye98/Desktop/datasets2'
train_dir = os.path.join(base_dir,'train')
validation_dir = os.path.join(base_dir,'test')
btz= 2

train_datagen = ImageDataGenerator(rescale = 1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
#train_generator = train_datagen.flow_from_directory(train_dir, batch_size=16, target_size=(224, 224), color_mode='rgb')
#val_generator = val_datagen.flow_from_directory(val_dir, batch_size=16, target_size=(224, 224), color_mode='rgb')
 
 

train_generator = train_datagen.flow_from_directory(train_dir,
    #모든 이미지를 150 X 150 크기로 바꾼다
    target_size = (150, 150),
    batch_size = btz, 
    #class_mode = 'binary'
) # 우선 이진분류로 학습(real vs stylegan3)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(150, 150),
    batch_size = btz,
    #class_mode = 'binary'
)
# Out:
# Found 1718 images belonging to 2 classes.
# Found 1718 images belonging to 2 classes.

# %%
def read_model(input_model_dir, sensor): # * 모델 가중치 불러오기
  model=model_from_json(open(os.path.join(input_model_dir,model_sub_dir,sensor + '_architecture.json')).read())
  model.load_weights(os.path.join(input_model_dir,model_sub_dir,sensor + '_model_weights.h5'))
  return model

# %%
from tensorflow.keras import Input
from tensorflow.keras.models import load_model
from tensorflow.keras import initializers, regularizers, metrics
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import BatchNormalization, Conv2D, Activation, Dense, GlobalAveragePooling2D, MaxPooling2D, ZeroPadding2D, Add
 
import os
import matplotlib.pyplot as plt
import numpy as np
import math
 
 
# number of classes
K = 1
 
 
input_tensor = Input(shape=(150, 150, 3), dtype='float32', name='input')
 
 
def conv1_layer(x):    
    x = ZeroPadding2D(padding=(3, 3))(x)
    x = Conv2D(64, (7, 7), strides=(2, 2))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = ZeroPadding2D(padding=(1,1))(x)
 
    return x   
 
    
 
def conv2_layer(x):         
    x = MaxPooling2D((3, 3), 2)(x)     
 
    shortcut = x
 
    for i in range(3):
        if (i == 0):
            x = Conv2D(64, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(256, (1, 1), strides=(1, 1), padding='valid')(x)
            shortcut = Conv2D(256, (1, 1), strides=(1, 1), padding='valid')(shortcut)            
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)
 
            x = Add()([x, shortcut])
            x = Activation('relu')(x)
            
            shortcut = x
 
        else:
            x = Conv2D(64, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(256, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])   
            x = Activation('relu')(x)  
 
            shortcut = x        
    
    return x
 
 
 
def conv3_layer(x):        
    shortcut = x    
    
    for i in range(4):     
        if(i == 0):            
            x = Conv2D(128, (1, 1), strides=(2, 2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv2D(512, (1, 1), strides=(1, 1), padding='valid')(x)
            shortcut = Conv2D(512, (1, 1), strides=(2, 2), padding='valid')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)            
 
            x = Add()([x, shortcut])    
            x = Activation('relu')(x)    
 
            shortcut = x              
        
        else:
            x = Conv2D(128, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(512, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])     
            x = Activation('relu')(x)
 
            shortcut = x      
            
    return x
 
 
 
def conv4_layer(x):
    shortcut = x        
  
    for i in range(6):     
        if(i == 0):            
            x = Conv2D(256, (1, 1), strides=(2, 2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv2D(1024, (1, 1), strides=(1, 1), padding='valid')(x)
            shortcut = Conv2D(1024, (1, 1), strides=(2, 2), padding='valid')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)
 
            x = Add()([x, shortcut]) 
            x = Activation('relu')(x)
 
            shortcut = x               
        
        else:
            x = Conv2D(256, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(1024, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])    
            x = Activation('relu')(x)
 
            shortcut = x      
 
    return x
 
 
 
def conv5_layer(x):
    shortcut = x    
  
    for i in range(3):     
        if(i == 0):            
            x = Conv2D(512, (1, 1), strides=(2, 2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv2D(2048, (1, 1), strides=(1, 1), padding='valid')(x)
            shortcut = Conv2D(2048, (1, 1), strides=(2, 2), padding='valid')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)            
 
            x = Add()([x, shortcut])  
            x = Activation('relu')(x)      
 
            shortcut = x               
        
        else:
            x = Conv2D(512, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(2048, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)           
            
            x = Add()([x, shortcut]) 
            x = Activation('relu')(x)       
 
            shortcut = x                  
 
    return x
 
 
 
x = conv1_layer(input_tensor)
x = conv2_layer(x)
x = conv3_layer(x)
x = conv4_layer(x)
x = conv5_layer(x)
 
x = GlobalAveragePooling2D()(x)
output_tensor = Dense(K, activation='softmax')(x)
 
resnet50 = Model(input_tensor, output_tensor)
resnet50.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 150, 150, 3  0           []
#                                 )]
#
#  zero_padding2d_4 (ZeroPadding2  (None, 156, 156, 3)  0          ['input[0][0]']
#  D)
#
#  conv2d_116 (Conv2D)            (None, 75, 75, 64)   9472        ['zero_padding2d_4[0][0]']
#
#  batch_normalization_106 (Batch  (None, 75, 75, 64)  256         ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_98 (Activation)     (None, 75, 75, 64)   0           ['batch_normalization_106[0][0]']
#
#  zero_padding2d_5 (ZeroPadding2  (None, 77, 77, 64)  0           ['activation_98[0][0]']
#  D)
#
#  max_pooling2d_12 (MaxPooling2D  (None, 38, 38, 64)  0           ['zero_padding2d_5[0][0]']
#  )
#
#  conv2d_117 (Conv2D)            (None, 38, 38, 64)   4160        ['max_pooling2d_12[0][0]']
#
#  batch_normalization_107 (Batch  (None, 38, 38, 64)  256         ['conv2d_117[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 38, 38, 64)   0           ['batch_normalization_107[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 38, 38, 64)   36928       ['activation_99[0][0]']
#
#  batch_normalization_108 (Batch  (None, 38, 38, 64)  256         ['conv2d_118[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 38, 38, 64)   0           ['batch_normalization_108[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 38, 38, 256)  16640       ['activation_100[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 38, 38, 256)  16640       ['max_pooling2d_12[0][0]']
#
#  batch_normalization_109 (Batch  (None, 38, 38, 256)  1024       ['conv2d_119[0][0]']
#  Normalization)
#
#  batch_normalization_110 (Batch  (None, 38, 38, 256)  1024       ['conv2d_120[0][0]']
#  Normalization)
#
#  add_32 (Add)                   (None, 38, 38, 256)  0           ['batch_normalization_109[0][0]',
#                                                                   'batch_normalization_110[0][0]']
#
#  activation_101 (Activation)    (None, 38, 38, 256)  0           ['add_32[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 38, 38, 64)   16448       ['activation_101[0][0]']
#
#  batch_normalization_111 (Batch  (None, 38, 38, 64)  256         ['conv2d_121[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 38, 38, 64)   0           ['batch_normalization_111[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 38, 38, 64)   36928       ['activation_102[0][0]']
#
#  batch_normalization_112 (Batch  (None, 38, 38, 64)  256         ['conv2d_122[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 38, 38, 64)   0           ['batch_normalization_112[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 38, 38, 256)  16640       ['activation_103[0][0]']
#
#  batch_normalization_113 (Batch  (None, 38, 38, 256)  1024       ['conv2d_123[0][0]']
#  Normalization)
#
#  add_33 (Add)                   (None, 38, 38, 256)  0           ['batch_normalization_113[0][0]',
#                                                                   'activation_101[0][0]']
#
#  activation_104 (Activation)    (None, 38, 38, 256)  0           ['add_33[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 38, 38, 64)   16448       ['activation_104[0][0]']
#
#  batch_normalization_114 (Batch  (None, 38, 38, 64)  256         ['conv2d_124[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 38, 38, 64)   0           ['batch_normalization_114[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 38, 38, 64)   36928       ['activation_105[0][0]']
#
#  batch_normalization_115 (Batch  (None, 38, 38, 64)  256         ['conv2d_125[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 38, 38, 64)   0           ['batch_normalization_115[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 38, 38, 256)  16640       ['activation_106[0][0]']
#
#  batch_normalization_116 (Batch  (None, 38, 38, 256)  1024       ['conv2d_126[0][0]']
#  Normalization)
#
#  add_34 (Add)                   (None, 38, 38, 256)  0           ['batch_normalization_116[0][0]',
#                                                                   'activation_104[0][0]']
#
#  activation_107 (Activation)    (None, 38, 38, 256)  0           ['add_34[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 19, 19, 128)  32896       ['activation_107[0][0]']
#
#  batch_normalization_117 (Batch  (None, 19, 19, 128)  512        ['conv2d_127[0][0]']
#  Normalization)
#
#  activation_108 (Activation)    (None, 19, 19, 128)  0           ['batch_normalization_117[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 19, 19, 128)  147584      ['activation_108[0][0]']
#
#  batch_normalization_118 (Batch  (None, 19, 19, 128)  512        ['conv2d_128[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 19, 19, 128)  0           ['batch_normalization_118[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 19, 19, 512)  66048       ['activation_109[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 19, 19, 512)  131584      ['activation_107[0][0]']
#
#  batch_normalization_119 (Batch  (None, 19, 19, 512)  2048       ['conv2d_129[0][0]']
#  Normalization)
#
#  batch_normalization_120 (Batch  (None, 19, 19, 512)  2048       ['conv2d_130[0][0]']
#  Normalization)
#
#  add_35 (Add)                   (None, 19, 19, 512)  0           ['batch_normalization_119[0][0]',
#                                                                   'batch_normalization_120[0][0]']
#
#  activation_110 (Activation)    (None, 19, 19, 512)  0           ['add_35[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 19, 19, 128)  65664       ['activation_110[0][0]']
#
#  batch_normalization_121 (Batch  (None, 19, 19, 128)  512        ['conv2d_131[0][0]']
#  Normalization)
#
#  activation_111 (Activation)    (None, 19, 19, 128)  0           ['batch_normalization_121[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 19, 19, 128)  147584      ['activation_111[0][0]']
#
#  batch_normalization_122 (Batch  (None, 19, 19, 128)  512        ['conv2d_132[0][0]']
#  Normalization)
#
#  activation_112 (Activation)    (None, 19, 19, 128)  0           ['batch_normalization_122[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 19, 19, 512)  66048       ['activation_112[0][0]']
#
#  batch_normalization_123 (Batch  (None, 19, 19, 512)  2048       ['conv2d_133[0][0]']
#  Normalization)
#
#  add_36 (Add)                   (None, 19, 19, 512)  0           ['batch_normalization_123[0][0]',
#                                                                   'activation_110[0][0]']
#
#  activation_113 (Activation)    (None, 19, 19, 512)  0           ['add_36[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 19, 19, 128)  65664       ['activation_113[0][0]']
#
#  batch_normalization_124 (Batch  (None, 19, 19, 128)  512        ['conv2d_134[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 19, 19, 128)  0           ['batch_normalization_124[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 19, 19, 128)  147584      ['activation_114[0][0]']
#
#  batch_normalization_125 (Batch  (None, 19, 19, 128)  512        ['conv2d_135[0][0]']
#  Normalization)
#
#  activation_115 (Activation)    (None, 19, 19, 128)  0           ['batch_normalization_125[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 19, 19, 512)  66048       ['activation_115[0][0]']
#
#  batch_normalization_126 (Batch  (None, 19, 19, 512)  2048       ['conv2d_136[0][0]']
#  Normalization)
#
#  add_37 (Add)                   (None, 19, 19, 512)  0           ['batch_normalization_126[0][0]',
#                                                                   'activation_113[0][0]']
#
#  activation_116 (Activation)    (None, 19, 19, 512)  0           ['add_37[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 19, 19, 128)  65664       ['activation_116[0][0]']
#
#  batch_normalization_127 (Batch  (None, 19, 19, 128)  512        ['conv2d_137[0][0]']
#  Normalization)
#
#  activation_117 (Activation)    (None, 19, 19, 128)  0           ['batch_normalization_127[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 19, 19, 128)  147584      ['activation_117[0][0]']
#
#  batch_normalization_128 (Batch  (None, 19, 19, 128)  512        ['conv2d_138[0][0]']
#  Normalization)
#
#  activation_118 (Activation)    (None, 19, 19, 128)  0           ['batch_normalization_128[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 19, 19, 512)  66048       ['activation_118[0][0]']
#
#  batch_normalization_129 (Batch  (None, 19, 19, 512)  2048       ['conv2d_139[0][0]']
#  Normalization)
#
#  add_38 (Add)                   (None, 19, 19, 512)  0           ['batch_normalization_129[0][0]',
#                                                                   'activation_116[0][0]']
#
#  activation_119 (Activation)    (None, 19, 19, 512)  0           ['add_38[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 10, 10, 256)  131328      ['activation_119[0][0]']
#
#  batch_normalization_130 (Batch  (None, 10, 10, 256)  1024       ['conv2d_140[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 10, 10, 256)  0           ['batch_normalization_130[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 10, 10, 256)  590080      ['activation_120[0][0]']
#
#  batch_normalization_131 (Batch  (None, 10, 10, 256)  1024       ['conv2d_141[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 10, 10, 256)  0           ['batch_normalization_131[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 10, 10, 1024  263168      ['activation_121[0][0]']
#                                 )
#
#  conv2d_143 (Conv2D)            (None, 10, 10, 1024  525312      ['activation_119[0][0]']
#                                 )
#
#  batch_normalization_132 (Batch  (None, 10, 10, 1024  4096       ['conv2d_142[0][0]']
#  Normalization)                 )
#
#  batch_normalization_133 (Batch  (None, 10, 10, 1024  4096       ['conv2d_143[0][0]']
#  Normalization)                 )
#
#  add_39 (Add)                   (None, 10, 10, 1024  0           ['batch_normalization_132[0][0]',
#                                 )                                 'batch_normalization_133[0][0]']
#
#  activation_122 (Activation)    (None, 10, 10, 1024  0           ['add_39[0][0]']
#                                 )
#
#  conv2d_144 (Conv2D)            (None, 10, 10, 256)  262400      ['activation_122[0][0]']
#
#  batch_normalization_134 (Batch  (None, 10, 10, 256)  1024       ['conv2d_144[0][0]']
#  Normalization)
#
#  activation_123 (Activation)    (None, 10, 10, 256)  0           ['batch_normalization_134[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 10, 10, 256)  590080      ['activation_123[0][0]']
#
#  batch_normalization_135 (Batch  (None, 10, 10, 256)  1024       ['conv2d_145[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 10, 10, 256)  0           ['batch_normalization_135[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 10, 10, 1024  263168      ['activation_124[0][0]']
#                                 )
#
#  batch_normalization_136 (Batch  (None, 10, 10, 1024  4096       ['conv2d_146[0][0]']
#  Normalization)                 )
#
#  add_40 (Add)                   (None, 10, 10, 1024  0           ['batch_normalization_136[0][0]',
#                                 )                                 'activation_122[0][0]']
#
#  activation_125 (Activation)    (None, 10, 10, 1024  0           ['add_40[0][0]']
#                                 )
#
#  conv2d_147 (Conv2D)            (None, 10, 10, 256)  262400      ['activation_125[0][0]']
#
#  batch_normalization_137 (Batch  (None, 10, 10, 256)  1024       ['conv2d_147[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 10, 10, 256)  0           ['batch_normalization_137[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 10, 10, 256)  590080      ['activation_126[0][0]']
#
#  batch_normalization_138 (Batch  (None, 10, 10, 256)  1024       ['conv2d_148[0][0]']
#  Normalization)
#
#  activation_127 (Activation)    (None, 10, 10, 256)  0           ['batch_normalization_138[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 10, 10, 1024  263168      ['activation_127[0][0]']
#                                 )
#
#  batch_normalization_139 (Batch  (None, 10, 10, 1024  4096       ['conv2d_149[0][0]']
#  Normalization)                 )
#
#  add_41 (Add)                   (None, 10, 10, 1024  0           ['batch_normalization_139[0][0]',
#                                 )                                 'activation_125[0][0]']
#
#  activation_128 (Activation)    (None, 10, 10, 1024  0           ['add_41[0][0]']
#                                 )
#
#  conv2d_150 (Conv2D)            (None, 10, 10, 256)  262400      ['activation_128[0][0]']
#
#  batch_normalization_140 (Batch  (None, 10, 10, 256)  1024       ['conv2d_150[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 10, 10, 256)  0           ['batch_normalization_140[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 10, 10, 256)  590080      ['activation_129[0][0]']
#
#  batch_normalization_141 (Batch  (None, 10, 10, 256)  1024       ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_130 (Activation)    (None, 10, 10, 256)  0           ['batch_normalization_141[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 10, 10, 1024  263168      ['activation_130[0][0]']
#                                 )
#
#  batch_normalization_142 (Batch  (None, 10, 10, 1024  4096       ['conv2d_152[0][0]']
#  Normalization)                 )
#
#  add_42 (Add)                   (None, 10, 10, 1024  0           ['batch_normalization_142[0][0]',
#                                 )                                 'activation_128[0][0]']
#
#  activation_131 (Activation)    (None, 10, 10, 1024  0           ['add_42[0][0]']
#                                 )
#
#  conv2d_153 (Conv2D)            (None, 10, 10, 256)  262400      ['activation_131[0][0]']
#
#  batch_normalization_143 (Batch  (None, 10, 10, 256)  1024       ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 10, 10, 256)  0           ['batch_normalization_143[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 10, 10, 256)  590080      ['activation_132[0][0]']
#
#  batch_normalization_144 (Batch  (None, 10, 10, 256)  1024       ['conv2d_154[0][0]']
#  Normalization)
#
#  activation_133 (Activation)    (None, 10, 10, 256)  0           ['batch_normalization_144[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 10, 10, 1024  263168      ['activation_133[0][0]']
#                                 )
#
#  batch_normalization_145 (Batch  (None, 10, 10, 1024  4096       ['conv2d_155[0][0]']
#  Normalization)                 )
#
#  add_43 (Add)                   (None, 10, 10, 1024  0           ['batch_normalization_145[0][0]',
#                                 )                                 'activation_131[0][0]']
#
#  activation_134 (Activation)    (None, 10, 10, 1024  0           ['add_43[0][0]']
#                                 )
#
#  conv2d_156 (Conv2D)            (None, 10, 10, 256)  262400      ['activation_134[0][0]']
#
#  batch_normalization_146 (Batch  (None, 10, 10, 256)  1024       ['conv2d_156[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 10, 10, 256)  0           ['batch_normalization_146[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 10, 10, 256)  590080      ['activation_135[0][0]']
#
#  batch_normalization_147 (Batch  (None, 10, 10, 256)  1024       ['conv2d_157[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 10, 10, 256)  0           ['batch_normalization_147[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 10, 10, 1024  263168      ['activation_136[0][0]']
#                                 )
#
#  batch_normalization_148 (Batch  (None, 10, 10, 1024  4096       ['conv2d_158[0][0]']
#  Normalization)                 )
#
#  add_44 (Add)                   (None, 10, 10, 1024  0           ['batch_normalization_148[0][0]',
#                                 )                                 'activation_134[0][0]']
#
#  activation_137 (Activation)    (None, 10, 10, 1024  0           ['add_44[0][0]']
#                                 )
#
#  conv2d_159 (Conv2D)            (None, 5, 5, 512)    524800      ['activation_137[0][0]']
#
#  batch_normalization_149 (Batch  (None, 5, 5, 512)   2048        ['conv2d_159[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 5, 5, 512)    0           ['batch_normalization_149[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 5, 5, 512)    2359808     ['activation_138[0][0]']
#
#  batch_normalization_150 (Batch  (None, 5, 5, 512)   2048        ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 5, 5, 512)    0           ['batch_normalization_150[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 5, 5, 2048)   1050624     ['activation_139[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 5, 5, 2048)   2099200     ['activation_137[0][0]']
#
#  batch_normalization_151 (Batch  (None, 5, 5, 2048)  8192        ['conv2d_161[0][0]']
#  Normalization)
#
#  batch_normalization_152 (Batch  (None, 5, 5, 2048)  8192        ['conv2d_162[0][0]']
#  Normalization)
#
#  add_45 (Add)                   (None, 5, 5, 2048)   0           ['batch_normalization_151[0][0]',
#                                                                   'batch_normalization_152[0][0]']
#
#  activation_140 (Activation)    (None, 5, 5, 2048)   0           ['add_45[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 5, 5, 512)    1049088     ['activation_140[0][0]']
#
#  batch_normalization_153 (Batch  (None, 5, 5, 512)   2048        ['conv2d_163[0][0]']
#  Normalization)
#
#  activation_141 (Activation)    (None, 5, 5, 512)    0           ['batch_normalization_153[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 5, 5, 512)    2359808     ['activation_141[0][0]']
#
#  batch_normalization_154 (Batch  (None, 5, 5, 512)   2048        ['conv2d_164[0][0]']
#  Normalization)
#
#  activation_142 (Activation)    (None, 5, 5, 512)    0           ['batch_normalization_154[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 5, 5, 2048)   1050624     ['activation_142[0][0]']
#
#  batch_normalization_155 (Batch  (None, 5, 5, 2048)  8192        ['conv2d_165[0][0]']
#  Normalization)
#
#  add_46 (Add)                   (None, 5, 5, 2048)   0           ['batch_normalization_155[0][0]',
#                                                                   'activation_140[0][0]']
#
#  activation_143 (Activation)    (None, 5, 5, 2048)   0           ['add_46[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 5, 5, 512)    1049088     ['activation_143[0][0]']
#
#  batch_normalization_156 (Batch  (None, 5, 5, 512)   2048        ['conv2d_166[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 5, 5, 512)    0           ['batch_normalization_156[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 5, 5, 512)    2359808     ['activation_144[0][0]']
#
#  batch_normalization_157 (Batch  (None, 5, 5, 512)   2048        ['conv2d_167[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 5, 5, 512)    0           ['batch_normalization_157[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 5, 5, 2048)   1050624     ['activation_145[0][0]']
#
#  batch_normalization_158 (Batch  (None, 5, 5, 2048)  8192        ['conv2d_168[0][0]']
#  Normalization)
#
#  add_47 (Add)                   (None, 5, 5, 2048)   0           ['batch_normalization_158[0][0]',
#                                                                   'activation_143[0][0]']
#
#  activation_146 (Activation)    (None, 5, 5, 2048)   0           ['add_47[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 2048)        0           ['activation_146[0][0]']
#  obalAveragePooling2D)
#
#  dense_6 (Dense)                (None, 1)            2049        ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 23,589,761
# Trainable params: 23,536,641
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
#Conv2D(채널 수, Conv2D filter크기, activation function, 입력데이터 크기)

#input_shape = (150,150,2)
#img_input = layers.Input(shape=input_shape)
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D(2, 2))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
#output=layers.Conv
model.compile(loss='binary_crossentropy', 
              optimizer=Adam(learning_rate=0.05),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_169 (Conv2D)         (None, 148, 148, 32)      896
#
#  max_pooling2d_13 (MaxPoolin  (None, 74, 74, 32)       0
#  g2D)
#
#  conv2d_170 (Conv2D)         (None, 72, 72, 32)        9248
#
#  max_pooling2d_14 (MaxPoolin  (None, 36, 36, 32)       0
#  g2D)
#
#  conv2d_171 (Conv2D)         (None, 34, 34, 64)        18496
#
#  max_pooling2d_15 (MaxPoolin  (None, 17, 17, 64)       0
#  g2D)
#
#  conv2d_172 (Conv2D)         (None, 15, 15, 64)        36928
#
#  max_pooling2d_16 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  conv2d_173 (Conv2D)         (None, 5, 5, 128)         73856
#
#  max_pooling2d_17 (MaxPoolin  (None, 2, 2, 128)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 128)               65664
#
#  dense_8 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 205,217
# Trainable params: 205,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_step = math.ceil(train_generator.n/btz)
valid_step = math.ceil(validation_generator.n/btz)
resnet50.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.001), metrics=['accuracy'])
history = resnet50.fit(
    train_generator,
    steps_per_epoch=train_step,
    epochs=20,
    validation_data = validation_generator,
    validation_steps = valid_step
)
# Out:
# Epoch 1/20
# 2022-03-21 17:14:42.562634: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 859/859 [==============================] - ETA: 0s - loss: 0.7190 - accuracy: 0.5000
# 2022-03-21 17:15:49.477938: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 859/859 [==============================] - 133s 150ms/step - loss: 0.7190 - accuracy: 0.5000 - val_loss: 0.7337 - val_accuracy: 0.5000
# Epoch 2/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6975 - accuracy: 0.5000 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 3/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6940 - accuracy: 0.5000 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 4/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6950 - accuracy: 0.5000 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 5/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6945 - accuracy: 0.5000 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 6/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6941 - accuracy: 0.5000 - val_loss: 0.6965 - val_accuracy: 0.5000
# Epoch 7/20
# 859/859 [==============================] - 127s 148ms/step - loss: 0.6939 - accuracy: 0.5000 - val_loss: 0.6950 - val_accuracy: 0.5000
# Epoch 8/20
# 859/859 [==============================] - 127s 148ms/step - loss: 0.6938 - accuracy: 0.5000 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 9/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6937 - accuracy: 0.5000 - val_loss: 0.7009 - val_accuracy: 0.5000
# Epoch 10/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 11/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.7091 - accuracy: 0.5000 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 12/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 13/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 14/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 15/20
# 859/859 [==============================] - 126s 146ms/step - loss: 0.6935 - accuracy: 0.5000 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 16/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 17/20
# 859/859 [==============================] - 127s 148ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 18/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 19/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 20/20
# 859/859 [==============================] - 128s 149ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000

# %%
acc=history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
test_loss, test_acc = resnet50.evaluate_generator(validation_generator, steps=valid_step, workers=4)
print(f'test loss : {test_loss:.4f} / test acc : {test_acc*100:.2f} %')
# Out:
# test loss : 0.6932 / test acc : 50.00 %
